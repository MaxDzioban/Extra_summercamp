# %% [markdown]
# <h1>Привіт!<p></h1><h2><b>Впродовж лекції ви ознайомилися з основами Python. Тому пропоную закодувати 6 додаткових задач, щоб краще зрозуміти цю тему. У разі успішного виконання всіх завдань ви зможете отримати приз - мерч Факультету або Самеркемпу!</b></h2>

# %% [markdown]
# <h2><i>
# Задача 1</i><p></h2>
# <h3>
# Напишіть програму, що зчитувала б з клавіатури натуральне число (number) та виводила суму всіх натуральних чисел менших за number, що є кратними 3 або 5. Приклад: для числа 10 це буде 23</p>
# </h3>
# <h5>

# %%
# Ваш код тут

# %% [markdown]
# <h2><i>
# Задача 2</i><p></h2>
# <h3>
# Напишіть програму, що зчитувала б з клавіатури натуральне число (number) та виводила б на екран добуток усіх натуральних чисел, що не перевищують n та не діляться на 7.</p></h3>
# <h4>
# <p>Приклад 1:</p>
# <p>3       <- Ввід n</p>
# <p>6       <- Вивід добутку ( 1, 2, 3 не перевищують 3 і не ділиться на 7)</p></h4>

# %%
# Ваш код тут

# %% [markdown]
# <h2><i>
# Задача 3</i><p></h2>
# <h3>
# Напишіть програму, що зчитувала б з клавіатури три числа, котрі означають початок циклу, кінець, крок = begin, end, step. Виведіть на екран суму чисел з цього циклу. Якщо значення begin більше, ніж end, ваша функція повинна повернути 0. Якщо end не є результатом цілого числа кроків, то не додавайте його до суми
# <h4>
# <p>Приклад:</p>
# <p>2       <- Ввід begin</p>
# <p>6       <- Ввід end</p>
# <p>2       <- Ввід step</p>
# <p>12       <- Вивід cуми, бо 2 + 4 + 6 = 12</p></h4>

# %%
# Ваш код тут

# %% [markdown]
# <h2><i>
# Задача 4</i><p></h2>
# <h3>
# Напишіть програму, що зчитувала б з клавіатури 5 імен, і перевіряє чи є вони вашими друзями. Імена ваших друзів мають містити тільки 4 букви. Програма має поверати список друзів</h3>
# <h4>
# <p>Приклад:</p>
# <p>John      <- Ввід</p>
# <p>Melon       <- Ввід </p>
# <p>Ivan      <- Ввід </p>
# <p>Lucas      <- Ввід </p>
# <p>Inna       <- Ввід </p>
# <p>['John','Ivan','Inna']<- Вивід ваших друзів</p></h4>

# %%
# Ваш код тут

# %% [markdown]
# <h2><i>
# Задача 5</i><p></h2>
# <h3>
# Напишіть програму, що зчитувала б з клавіатури рядок, котрий відображає список з 5 мотузок, де довжина кожної мотузки є додатним цілим числом. На кожному кроці ви повинні зменшити всі мотузки на довжину найменшої мотузки. Цей крок повторюватиметься, поки не залишиться жодної мотузки. Виведіть на екран кількість мотузок, що залишаються перед кожним кроком.<h3>
#
# <h4>
# <pre>        3 3 2 9 7   ( 5 left)
# <p>
#
# step 1:          1 1 0 7 5   ( 4 left)
#
# step 2:          0 0 0 6 4   ( 2 left)
#
# step 3:          0 0 0 0 2   ( 1 left)
#
# step 4:          0 0 0 0 0
#
# Hence the result is [5, 4, 2, 1]
# </h4>

# %%
# Ваш код тут

# %% [markdown]
# <h2><i>
# Задача 6</i><p></h2>
# <h3>
# Напишіть програму, що зчитувала з клавіатури число і вивела на екран повідомлення (булеве значення), чи є воно степенем числа 2.<h3>
# <h4>
# <p>Приклад:</p>
# <p>Input: n = 16</p>
# <p>Output: true</p>
# <p>Explanation: 2^4 = 16</p>

# %%
# Ваш код тут
